# %%
#!pip install tokenizers
#!pip install gensim

# %%
import os
import pandas as pd

from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import sagemaker
from sagemaker import get_execution_role
import sagemaker_pyspark

#Visualizaciones y Varios
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import boto3
role = get_execution_role()

jars = sagemaker_pyspark.classpath_jars()
classpath = ":".join(sagemaker_pyspark.classpath_jars())
spark = (SparkSession.builder
         .config("spark.driver.extraClassPath", classpath)
         .config("spark.executor.memory","60g")
         .config("spark.driver.memory","60g")
         .config("spark.driver.maxResultSize", "0")
         .master("local[*]").getOrCreate())

spark.conf.set("spark.sql.caseSensitive", "true")

# %%
bucket = 'politicos-dataset-us-east-1'
region = 'us-east-1'
prefix = 'gpt2_fine_tune/tweets_politicos'
spark._jsc.hadoopConfiguration().set('fs.s3a.endpoint', 's3.{}.amazonaws.com'.format(region))

# %%
SDF = spark.read.parquet('s3a://{}/{}/parquet'.format(bucket, prefix))

# %%
SDF.count()
# Out:
# 170306

# %%
df = SDF.toPandas()
df
# Out:
#                      id_str                        hashtags     screen_name  \
# 0       1134966472260931585  [CuentaPública, ChileenMarcha]      _alecandia
# 1       1134991775045685248      [Araucanía, CuentaPública]    nonaossandon
# 2       1135003138753277956                 [CuentaPública]     feguigurenc
# 3       1135008118277124096                 [CuentaPública]    ANDRESCELISM
# 4       1135008271104974848                 [Cuentapublica]  Diego_Schalper
# ...                     ...                             ...             ...
# 170301  1285265827017756672          [CuidaTuVida, COVID19]      MuniColina
# 170302  1285296001125888001              [MercadoCampesino]      MuniColina
# 170303  1285663758933786624                              []    renesaffirio
# 170304  1285690326909427714                              []  HarryJurgensen
# 170305  1285759908332425217                              []   GarinDiputado
#
#         target_id                                               text  \
# 0              57  Ya estamos en el Congreso con los subses @Caro...
# 1             681  ⭕ "Combatir con máxima voluntad y firmeza, sie...
# 2             176  #CuentaPública\n📢ANUNCIO| Nuestro Presidente a...
# 3             240  El agua es un tema muy importante para nuestra...
# 4             287  Bien límite a la reelección. Ojalá reforma al ...
# ...           ...                                                ...
# 170301        601  #CuidaTuVida | ¡Córtala de una vez!\nEn tiempo...
# 170302        601  El #MercadoCampesino de @INDAP_Chile ya cuenta...
# 170303        476  Hoy Cámara Diputados aprobó y despachó a ley p...
# 170304        503  Nos reunimos con alcaldes de la región para da...
# 170305        698  @lingandmol @jota_De_Munoz @clausanhueza no ha...
#
#                                                  entities  \
# 0       [(42, 52, 0.990331768989563, CarolCBown, PERSO...
# 1       [(279, 302, 0.9772765636444092, https://t.co/A...
# 2       [(33, 43, 0.7224394679069519, Presidente, PERS...
# 3       [(93, 111, 0.9997791647911072, 26 nuevos embal...
# 4       [(94, 101, 0.7375357747077942, semanas, QUANTI...
# ...                                                   ...
# 170301  [(27, 34, 0.7483243942260742, una vez, QUANTIT...
# 170302  [(24, 36, 0.6468220949172974, @INDAP_Chile, OR...
# 170303  [(0, 3, 0.9184558391571045, Hoy, DATE), (4, 20...
# 170304  [(17, 25, 0.5282663702964783, alcaldes, PERSON...
# 170305  [(1, 11, 0.9975453019142151, lingandmol, PERSO...
#
#                                               key_phrases sentiment  \
# 0                                                      []   NEUTRAL
# 1                                                      []  NEGATIVE
# 2       [(0, 14, 0.9999927282333374, #CuentaPública), ...   NEUTRAL
# 3                  [(11, 18, 0.656255841255188, un tema)]   NEUTRAL
# 4       [(5, 11, 0.8332874178886414, límite), (14, 27,...   NEUTRAL
# ...                                                   ...       ...
# 170301  [(0, 12, 0.9999967813491821, #CuidaTuVida), (2...  NEGATIVE
# 170302  [(3, 20, 0.9999831914901733, #MercadoCampesino...   NEUTRAL
# 170303  [(4, 20, 0.8305284976959229, Cámara Diputados)...   NEUTRAL
# 170304                                                 []   NEUTRAL
# 170305                                                 []   NEUTRAL
#
#                         dt  Partido      Coalicion  \
# 0      2019-06-01 23:34:28  IND-GOB    Chile Vamos
# 1      2019-06-02 01:15:00       RN    Chile Vamos
# 2      2019-06-02 02:00:10       RN    Chile Vamos
# 3      2019-06-02 02:19:57       RN    Chile Vamos
# 4      2019-06-02 02:20:33       RN    Chile Vamos
# ...                    ...      ...            ...
# 170301 2020-07-20 17:30:26      UDI    Chile Vamos
# 170302 2020-07-20 19:30:20      UDI    Chile Vamos
# 170303 2020-07-21 19:51:41      IND  Independiente
# 170304 2020-07-21 21:37:15       RN    Chile Vamos
# 170305 2020-07-22 02:13:45       RD  Frente Amplio
#
#                                                text_clean  \
# 0       Ya estamos en el Congreso con los subses @Caro...
# 1       ⭕ "Combatir con máxima voluntad y firmeza, sie...
# 2       #CuentaPública\n📢ANUNCIO| Nuestro Presidente a...
# 3       El agua es un tema muy importante para nuestra...
# 4       Bien límite a la reelección. Ojalá reforma al ...
# ...                                                   ...
# 170301  #CuidaTuVida | ¡Córtala de una vez!\nEn tiempo...
# 170302  El #MercadoCampesino de @INDAP_Chile ya cuenta...
# 170303  Hoy Cámara Diputados aprobó y despachó a ley p...
# 170304  Nos reunimos con alcaldes de la región para da...
# 170305  @lingandmol @jota_De_Munoz @clausanhueza no ha...
#
#                                                 tokenized
# 0       [ya, estamos, en, el, congreso, con, los, subs...
# 1       [⭕, "combatir, con, máxima, voluntad, y, firme...
# 2       [#cuentapública, 📢anuncio|, nuestro, president...
# 3       [el, agua, es, un, tema, muy, importante, para...
# 4       [bien, límite, a, la, reelección., ojalá, refo...
# ...                                                   ...
# 170301  [#cuidatuvida, |, ¡córtala, de, una, vez!, en,...
# 170302  [el, #mercadocampesino, de, @indap_chile, ya, ...
# 170303  [hoy, cámara, diputados, aprobó, y, despachó, ...
# 170304  [nos, reunimos, con, alcaldes, de, la, región,...
# 170305  [@lingandmol, @jota_de_munoz, @clausanhueza, n...
#
# [170306 rows x 13 columns]

# %%
#!pip install fastparquet

# %%
prefix = 'gpt2_fine_tune/tweets_politicos/pandas/parquet'
df.to_parquet('s3://{}/{}'.format(bucket, prefix), compression='GZIP')
